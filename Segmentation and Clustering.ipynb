# %% [markdown]
# Import necissary packages and read in the tables that are on the wiki page:

# %%
pip install geocoder
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# %% [markdown]
# Discover how many tables there are on the wiki page:

# %%
len(df)
# Out:
# 3

# %% [markdown]
# Find the table out of the 3 using indexing the cooresonds to the desired wiki table:

# %%
df[0]
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %%
Toronto = df[0]

# %% [markdown]
# Select the rows within the Toronto table that contain 'Not assigned' for the column 'Borough'

# %%
indexNames = Toronto[ Toronto['Borough'] == 'Not assigned' ].index

# %% [markdown]
# Delete these selected rows from the table:

# %%
Toronto.drop(indexNames , inplace=True)

# %% [markdown]
# Show the new table making sure there are no rows with the values 'Not assigned':

# %%
Toronto
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# Show how many rows are in the able:

# %%
Toronto.shape
# Out:
# (103, 3)

# %% [markdown]
# Sort all values by postal code column to make sure they are in asending order so they stack up with geodata CSV

# %%
Toronto2 = Toronto.sort_values(by='Postal Code', axis=0, ascending=True)
Toronto2
# Out:
#     Postal Code      Borough  \
# 9           M1B  Scarborough
# 18          M1C  Scarborough
# 27          M1E  Scarborough
# 36          M1G  Scarborough
# 45          M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 107         M9P    Etobicoke
# 116         M9R    Etobicoke
# 143         M9V    Etobicoke
# 152         M9W    Etobicoke
#
#                                          Neighbourhood
# 9                                       Malvern, Rouge
# 18              Rouge Hill, Port Union, Highland Creek
# 27                   Guildwood, Morningside, West Hill
# 36                                              Woburn
# 45                                           Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 107                                          Westmount
# 116  Kingsview Village, St. Phillips, Martin Grove ...
# ...

# %% [markdown]
# Check to make sure postal code column is in ascending order

# %%
Toronto_postal_list = Toronto2['Postal Code'].tolist()
Toronto_postal_list
# Out:
# ['M1B',
#  'M1C',
#  'M1E',
#  'M1G',
#  'M1H',
#  'M1J',
#  'M1K',
#  'M1L',
#  'M1M',
#  'M1N',
#  'M1P',
#  'M1R',
#  'M1S',
#  'M1T',
#  'M1V',
#  'M1W',
#  'M1X',
#  'M2H',
#  'M2J',
#  'M2K',
#  'M2L',
#  'M2M',
#  'M2N',
#  'M2P',
#  'M2R',
#  'M3A',
#  'M3B',
#  'M3C',
#  'M3H',
#  'M3J',
#  'M3K',
#  'M3L',
#  'M3M',
#  'M3N',
#  'M4A',
#  'M4B',
#  'M4C',
#  'M4E',
#  'M4G',
#  'M4H',
#  'M4J',
#  'M4K',
#  'M4L',
#  'M4M',
#  'M4N',
#  'M4P',
#  'M4R',
#  'M4S',
#  'M4T',
#  'M4V',
#  'M4W',
#  'M4X',
#  'M4Y',
#  'M5A',
#  'M5B',
#  'M5C',
#  'M5E',
#  'M5G',
#  'M5H',
#  'M5J',
#  'M5K',
#  'M5L',
#  'M5M',
#  'M5N',
#  'M5P',
#  'M5R',
#  'M5S',
#  'M5T',
#  'M5V',
#  'M5W',
#  'M5X',
#  'M6A',
#  'M6B',
#  'M6C',
#  'M6E',
#  'M6G',
#  'M6H',
#  'M6J',
#  'M6K',
#  'M6L',
#  'M6M',
#  'M6N',
#  'M6P',
#  'M6R',
#  'M6S',
#  'M7A',
#  'M7R',
#  'M7Y',
#  'M8V',
#  'M8W',
#  'M8X',
#  'M8Y',
#  'M8Z',
#  'M9A',
#  'M9B',
#  'M9C',
#  'M9L',
#  'M9M',
#  'M9N',
#  'M9P',
# ...

# %% [markdown]
# Read in CSV file of geodata

# %%
geodata = pd.read_csv('https://cocl.us/Geospatial_data')
geodata.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Select rows in geodata CSV that coorespond to the toronto postal codes array

# %%
Tor_lat_lng = geodata.loc[geodata['Postal Code'].isin(Toronto_postal_list)]
Tor_lat_lng
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# Convert column values of tables: toronto2 & Tor_lat_lng into list arrays

# %%
col1 = Toronto2['Postal Code'].to_list()
col2 = Toronto2['Borough'].to_list()
col3 = Toronto2['Neighbourhood'].to_list()
col4 = Tor_lat_lng['Latitude'].to_list()
col5 = Tor_lat_lng['Longitude'].to_list()

# %% [markdown]
# Create final table by combinging all list arrays as columns

# %%
final_table = pd.DataFrame(list(zip(col1, col2,col3, col4, col5)), 
               columns =['Postal Code', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude']) 
final_table
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# ...
