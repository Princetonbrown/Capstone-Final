# %% [markdown]
# # Business Problem
#
# If the city of Minneaoplis could only afford 2 scooter maintenance facilities what 3 neighborhoods would be the best for building these facilities? The city of Minneapolis started a new scooter pilot program in 2019 to introduce a new form of public transportation.
#
# __Some of the main problems that we've seen from this pilot program are:__
# - How to balance a limited suppply of scooters within the city so that we meet consumer demand
# - How to ensure all scooters are charged throughout the day
# - How to ensure there aren't an overuse of scooters congesting walkways and streets within the city
#
# To solve these problems we would like to build scooter maintenance facilities around the city that are city owned and service all scooter types / scooter companies.
#
# __Projected benefits of Scooter facilities:__
#  - House extra scooters for re-distribution
#  - Balance the amount of scooters in a zone
#  - Repair scooters
#  - Charge scooters so there are less on the street
#  - Create jobs
#
# __Our criteria for deciding where to place these facilities:__
#  - Scooter Congestion Ratio (SCR) of each neighborhood. (# of scooters / pop. density)
#  - Number of transportation centers within each neighborhood (FrourSqure)
#  - Average distance away from key transit locations (GeoCoder)

# %% [markdown]
# # Data

# %% [markdown]
# Pilot program date range: May 17th, 2019 to January 14th, 2020
#
# ###### (243 days, or 7 months and 29 days.)
#
# ###### Scooter data: https://opendata.minneapolismn.gov/datasets/scooter-availability-2019/data?page=63408

# %% [markdown]
# # Methodology

# %% [markdown]
# Import and install necessary libaries

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import numpy as np
import sklearn.neighbors

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge geopy --yes #uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim #convert an address into latitude and longitude values

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
# Load in minneapolis scooter data
scooter_data = pd.read_csv('https://opendata.arcgis.com/datasets/47af2f88d31f45ccaaf945dbcc8f9665_0.csv')
scooter_data.head()
# Out:
#                  PollTime CompanyName  NumberAvailable ClosestCenterlineID  \
# 0  2019/05/16 19:00:00+00        Lime                1            10122.00
# 1  2019/05/16 19:00:00+00        Lime                1            10464.00
# 2  2019/05/16 19:00:00+00        Lime                1            10801.00
# 3  2019/05/16 19:00:00+00        Lime                1            11395.00
# 4  2019/05/16 19:00:00+00        Lime                1            13067.00
#
#   ClosestCenterlineType     Neighborhood  ESRI_OID
# 0                street  Webber - Camden         1
# 1                street   Lind - Bohanon         2
# 2                street     Audubon Park         3
# 3                street            CARAG         4
# 4                street        Minnehaha         5

# %%
n = len(scooter_data.index)

print("Number of rows in table:", n)
# Out:
# Number of rows in table: 486378

# %%
u = len(pd.unique(scooter_data['CompanyName']))

print("Number of unique scooter companies in Minneapolis :", u)
# Out:
# Number of unique scooter companies in Minneapolis : 3

# %%
scooter_data['ClosestCenterlineType'].value_counts()
# Out:
# street    443889
# trail      42489
# Name: ClosestCenterlineType, dtype: int64

# %%
b = 443889 / 42489

print("How many times more likely a scooter was parked on the street:", b)
# Out:
# How many times more likely a scooter was parked on the street: 10.44715102732472

# %% [markdown]
# Using a few quick pandas analysis tools note that our scooter facility will need to serve __3 different scooter companies__. In addition, we find the majority of scooters were approximately __10.8 times more available on the street__ than scooters on a trail. This indicates we should build our facilities so that they're at least 10x more easily accessible by street. In this next section let's find which neighborhoods had the highest amount of available scooters. We begin this process by creating a new dataframe using the __drop__ function to eliminate all unecissary columns.

# %%
scooter_data1 = scooter_data.drop(['PollTime','PollTime', 'CompanyName', 'ClosestCenterlineID', 'ClosestCenterlineType','ESRI_OID'], axis=1)
scooter_data1
# Out:
#         NumberAvailable                      Neighborhood
# 0                     1                   Webber - Camden
# 1                     1                    Lind - Bohanon
# 2                     1                      Audubon Park
# 3                     1                             CARAG
# 4                     1                         Minnehaha
# ...                 ...                               ...
# 486373                1  Steven's Square - Loring Heights
# 486374                1   Prospect Park - East River Road
# 486375                1           University of Minnesota
# 486376                1                          Ericsson
# 486377                2                        Logan Park
#
# [486378 rows x 2 columns]

# %%
# use group function to group data by neighborhood
scooter_data2 = scooter_data1.groupby(['Neighborhood']).sum()
scooter_data2
# Out:
#                NumberAvailable
# Neighborhood
# Armatage                   561
# Audubon Park              2671
# Bancroft                   968
# Beltrami                  1387
# Bottineau                10674
# ...                        ...
# West Calhoun              4160
# Whittier                 20491
# Willard - Hay             5986
# Windom                     539
# Windom Park               2494
#
# [87 rows x 1 columns]

# %%
# use sort function to show the number of available scooters in descending
scooter_data3 = scooter_data2.sort_values(by='NumberAvailable', ascending=False)
scooter_data3
# Out:
#                           NumberAvailable
# Neighborhood
# Downtown West                      105251
# Marcy Holmes                        67993
# University of Minnesota             52720
# Cedar Riverside                     41160
# North Loop                          39465
# ...                                   ...
# Morris Park                           282
# Kenny                                 207
# Page                                  180
# Camden Industrial                     129
# Humboldt Industrial Area               53
#
# [87 rows x 1 columns]

# %%
# list of 10 neighborhoods with greatest scooter availability
scooter_data3.nlargest(10, columns='NumberAvailable', keep='first')
# Out:
#                                  NumberAvailable
# Neighborhood
# Downtown West                             105251
# Marcy Holmes                               67993
# University of Minnesota                    52720
# Cedar Riverside                            41160
# North Loop                                 39465
# Prospect Park - East River Road            26602
# Loring Park                                24892
# Como                                       24487
# Holland                                    24380
# Hawthorne                                  23481

# %% [markdown]
# In the section above we have ordered the neighborhoods in descending order from greatest to least number of avialable scooters. With this list we easily see the top 10 neighborhoods of highest scooter concentration. Next let's find the population density of each neighborhood by  __scraping__ wikipedia pages. This data will be useful in determining which of the top neighborhoods require a maintentance facility the most based on the number of people living within a neighborhood, and it's scooter availability. We can also get the zip code  of each neighborhood. Using __geocode__ along with each neighborhood's zip code we can then generate latitude and longitude values for each neighborhood.

# %%
url='https://en.wikipedia.org/wiki/Downtown_West,_Minneapolis'
df=pd.read_html(url, header=0)[0]
df
# Out:
#                                         Downtown West  \
# 0                                        Neighborhood
# 1   Location of Downtown West within the U.S. city...
# 2                                             Country
# 3                                               State
# 4                                              County
# 5                                                City
# 6                                           Community
# 7                                             Area[1]
# 8                                             • Total
# 9                                Population (2010)[2]
# 10                                            • Total
# 11                                          • Density
# 12                                          Time zone
# 13                                     • Summer (DST)
# 14                                           ZIP code
# 15                                       Area code(s)
#
#                                       Downtown West.1
# 0                                        Neighborhood
# 1   Location of Downtown West within the U.S. city...
# 2                                       United States
# 3                                           Minnesota
# 4                                            Hennepin
# 5                                         Minneapolis
# 6                                             Central
# 7                                             Area[1]
# 8                              0.759 sq mi (1.97 km2)
# 9                                Population (2010)[2]
# 10                                               5781
# 11                            7,600/sq mi (2,900/km2)
# 12                                        UTC-6 (CST)
# 13                                        UTC-5 (CDT)
# 14           55401, 55402, 55403, 55404, 55415, 55487
# 15                                                612

# %%
url='https://en.wikipedia.org/wiki/Marcy-Holmes,_Minneapolis'
df=pd.read_html(url, header=0)[0]
df
# Out:
#                                          Marcy-Holmes  \
# 0                                        Neighborhood
# 1   Location of Marcy-Holmes within the U.S. city ...
# 2                                             Country
# 3                                               State
# 4                                              County
# 5                                                City
# 6                                           Community
# 7                                             Area[1]
# 8                                             • Total
# 9                                Population (2010)[2]
# 10                                            • Total
# 11                                          • Density
# 12                                          Time zone
# 13                                     • Summer (DST)
# 14                                           ZIP code
# 15                                       Area code(s)
# 16                                            Website
#
#                                        Marcy-Holmes.1
# 0                                        Neighborhood
# 1   Location of Marcy-Holmes within the U.S. city ...
# 2                                       United States
# 3                                           Minnesota
# 4                                            Hennepin
# 5                                         Minneapolis
# 6                                          University
# 7                                             Area[1]
# 8                              0.825 sq mi (2.14 km2)
# 9                                Population (2010)[2]
# 10                                              10015
# 11                           12,000/sq mi (4,700/km2)
# 12                                        UTC-6 (CST)
# 13                                        UTC-5 (CDT)
# 14                                              55414
# 15                                                612
# 16                        http://www.marcy-holmes.org

# %%
url='https://en.wikipedia.org/wiki/University_(neighborhood),_Minneapolis'
df=pd.read_html(url, header=0)[0]
df
# Out:
#                                            University  \
# 0                                        Neighborhood
# 1   The University of Minnesota's Minneapolis camp...
# 2   Location of University within the U.S. city of...
# 3                                             Country
# 4                                               State
# 5                                              County
# 6                                                City
# 7                                           Community
# 8                                             Area[1]
# 9                                             • Total
# 10                               Population (2010)[2]
# 11                                            • Total
# 12                                          • Density
# 13                                          Time zone
# 14                                     • Summer (DST)
# 15                                           ZIP code
# 16                                       Area code(s)
#
#                                          University.1
# 0                                        Neighborhood
# 1   The University of Minnesota's Minneapolis camp...
# 2   Location of University within the U.S. city of...
# 3                                       United States
# 4                                           Minnesota
# 5                                            Hennepin
# 6                                         Minneapolis
# 7                                          University
# 8                                             Area[1]
# 9                              0.668 sq mi (1.73 km2)
# 10                               Population (2010)[2]
# 11                                               5421
# 12                            8,100/sq mi (3,100/km2)
# 13                                        UTC-6 (CST)
# 14                                        UTC-5 (CDT)
# 15                                55414, 55454, 55455
# 16                                                612

# %%
url='https://en.wikipedia.org/wiki/Cedar-Riverside,_Minneapolis'
df=pd.read_html(url, header=0)[0]
df
# Out:
#                              Cedar-RiversideWest Bank  \
# 0                                        Neighborhood
# 1                    Nickname(s): Little Mogadishu[1]
# 2   Location of Cedar-Riverside within the U.S. ci...
# 3   Coordinates: 44°58′00″N 93°14′36″W﻿ / ﻿44.9666...
# 4                                             Country
# 5                                               State
# 6                                              County
# 7                                                City
# 8                                           Community
# 9                                             Area[2]
# 10                                            • Total
# 11                               Population (2010)[3]
# 12                                            • Total
# 13                                          • Density
# 14                                          Time zone
# 15                                     • Summer (DST)
# 16                                           ZIP code
# 17                                       Area code(s)
#
#                            Cedar-RiversideWest Bank.1
# 0                                        Neighborhood
# 1                    Nickname(s): Little Mogadishu[1]
# 2   Location of Cedar-Riverside within the U.S. ci...
# 3   Coordinates: 44°58′00″N 93°14′36″W﻿ / ﻿44.9666...
# 4                                       United States
# 5                                           Minnesota
# 6                                            Hennepin
# 7                                         Minneapolis
# 8                                          University
# 9                                             Area[2]
# 10                             0.549 sq mi (1.42 km2)
# 11                               Population (2010)[3]
# 12                                               8094
# 13                           15,000/sq mi (5,700/km2)
# 14                                        UTC-6 (CST)
# 15                                        UTC-5 (CDT)
# 16                                              55454
# 17                                                612

# %%
url='https://en.wikipedia.org/wiki/North_Loop,_Minneapolis'
df=pd.read_html(url, header=0)[0]
df
# Out:
#              North LoopMarket Square, Market District  \
# 0                                        Neighborhood
# 1                 Nickname(s): The Warehouse District
# 2   Location of North Loop within the U.S. city of...
# 3                                             Country
# 4                                               State
# 5                                              County
# 6                                                City
# 7                                           Community
# 8                                             Area[1]
# 9                                             • Total
# 10                               Population (2010)[2]
# 11                                            • Total
# 12                                          • Density
# 13                                          Time zone
# 14                                     • Summer (DST)
# 15                                           ZIP code
# 16                                       Area code(s)
#
#            North LoopMarket Square, Market District.1
# 0                                        Neighborhood
# 1                 Nickname(s): The Warehouse District
# 2   Location of North Loop within the U.S. city of...
# 3                                       United States
# 4                                           Minnesota
# 5                                            Hennepin
# 6                                         Minneapolis
# 7                                             Central
# 8                                             Area[1]
# 9                              0.837 sq mi (2.17 km2)
# 10                               Population (2010)[2]
# 11                                               4291
# 12                            5,100/sq mi (2,000/km2)
# 13                                        UTC-6 (CST)
# 14                                        UTC-5 (CDT)
# 15                         55401, 55403, 55405, 55411
# 16                                                612

# %%
url='https://en.wikipedia.org/wiki/Prospect_Park,_Minneapolis'
df=pd.read_html(url, header=0)[0]
df
# Out:
#                         Prospect ParkEast Minneapolis  \
# 0                                        Neighborhood
# 1   Prospect Park viewed from Stadium Village, wit...
# 2                  Nickname(s): The Angle, Tower Hill
# 3   Location of Prospect Park neighborhood within ...
# 4   Coordinates: 44°58′08″N 93°12′45″W﻿ / ﻿44.9688...
# 5                                             Country
# 6                                               State
# 7                                              County
# 8                                                City
# 9                                           Community
# 10                                Founded and Platted
# 11                                         Founded by
# 12                                          Named for
# 13                                  City Council Ward
# 14                                         Government
# 15                                    • Councilmember
# 16                                            Area[1]
# 17                                            • Total
# 18                                          Elevation
# 19                               Population (2010)[2]
# 20                                            • Total
# 21                                          • Density
# 22                                          Time zone
# 23                                     • Summer (DST)
# 24                                        Postal code
# 25                                       Area code(s)
# 26                                            Website
#
#                       Prospect ParkEast Minneapolis.1
# 0                                        Neighborhood
# 1   Prospect Park viewed from Stadium Village, wit...
# 2                  Nickname(s): The Angle, Tower Hill
# 3   Location of Prospect Park neighborhood within ...
# 4   Coordinates: 44°58′08″N 93°12′45″W﻿ / ﻿44.9688...
# 5                                       United States
# 6                                           Minnesota
# 7                                            Hennepin
# 8                                         Minneapolis
# 9                                          University
# 10                                               1885
# 11                                       Louis Menage
# 12                           Prospect Park (Brooklyn)
# 13                                                  2
# 14                                         Government
# 15                                         Cam Gordon
# 16                                            Area[1]
# 17                             1.241 sq mi (3.21 km2)
# 18                                     951 ft (284 m)
# 19                               Population (2010)[2]
# 20                                               7457
# 21                            6,000/sq mi (2,300/km2)
# 22                                        UTC-6 (CST)
# 23                                        UTC-5 (CDT)
# 24                                              55414
# 25                                                612
# 26                              http://www.pperr.org/

# %%
# create dataframe with postal codes for each abbreviated neighborhood to see overlapping of postal codes 

data = {
    '55401': ['dtw', 'nl','x'],
    '55402': ['dtw','x','x'],
    '55403': ['dtw', 'nl','x'],
    '55404': ['dtw','x','x'],
    '55405': ['nl','x','x'],
    '55411': ['nl','x','x'],
    '55414': ['mh', 'u', 'pp'],
    '55415': ['dtw','x','x'],
    '55454': ['u', 'cr','x'],
    '55455': ['u','x','x'],
    '55487': ['dtw','x','x']}
    
    
postal_table = pd.DataFrame (data, columns = ['55401','55402','55403','55404','55405','55411','55414','55415','55454','55455','55487']
                   
                  )
postal_table
# Out:
#   55401 55402 55403 55404 55405 55411 55414 55415 55454 55455 55487
# 0   dtw   dtw   dtw   dtw    nl    nl    mh   dtw     u     u   dtw
# 1    nl     x    nl     x     x     x     u     x    cr     x     x
# 2     x     x     x     x     x     x    pp     x     x     x     x

# %% [markdown]
# From the table we can more easily visualize which postal codes overlap with multiple neighborhoods. In order to give each neighborhood a unique postal code so that each neighborhood can be assigned a unique coordinate, we manually assign the postal codes to each neighborhood so that doubling is minimized. If a neighborhood is uniquely assigned to a postal code, meaning, there are no other neighborhoods under a specific postal code, than this postal code is assigned to that neighborhood. For example, if a postal code was shared by multiple neighborhoods but there is only one unique neighborhood this postal code is assigned to than the unique neighborhood gets the postal code. The only neighborhoods that will share the same postal code are Marcy Holmes and Prospect Park, since these neighborhoods have the same unique postal code of 55414.

# %%
# For loop to print out latitude and longitude coordinates for each postal code
postal = ['55404', '55414', '55455', '55454', '55405', '55414'] 
for x in postal:
    address = x
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print(latitude, longitude)
# Out:
# 44.96109575 -93.255894125
# 44.98711935 -93.24115775
# 44.97473309462231 -93.23407422863202
# 44.9676909 -93.23853524743203
# 44.957127150000005 -93.30278685186671
# 44.98711935 -93.24115775

# %% [markdown]
# Now we calculate the scooter congestion ratio (SCR). We are assuming a high population density correlates with more congested living as more people are packed into a smaller space. We can devide the number of scooters available by the population density for each neighborhood to get a "scooter congestion ratio." Scooter congestion is linked to cluttering of streets/sidewalks, higher scooter demand, and/or scooters in need of powering.
#
# __Scooter congestion ratio (SCR) = (# of scooters) / (population density)__

# %%
scooters_list = [136050,91214,66801,52683,49052,36927]
pop_density_list = [2900,4700,3100,5700,2000,2300]

res = [i / j for i, j in zip(scooters_list, pop_density_list)]
print(res)
# Out:
# [46.91379310344828, 19.407234042553192, 21.548709677419353, 9.242631578947368, 24.526, 16.055217391304346]

# %%
# create pandas dataframe to easily visualize which neighborhoods are most congested.

data = {'neighborhood': ['Downtown West','Marcy Holmes','University of Minnesota','Cedar Riverside','North Loop','Prospect Park'],
        'scooters':  ['105251', '67993','52720','41160','39465','26602'],
        'pop density (/km^2)': ['2,900', '4,700','3,100','5,700','2,000','2,300'],
        'SCR': ['46.914','19.407','21.549','9.243','24.526','16.055'],
        'Postal Code': ['55404', '55414', '55455', '55454', '55405', '55414'],
        'latitude': ['44.96109575', '44.98711935', '44.97473309462231', '44.9676909', '44.957127150000005', '44.9710'],
        'longitude': ['-93.255894125', '-93.24115775', '-93.23407422863205', '-93.23853524743203', '-93.30278685186671', '-93.2153']
       }

table1 = pd.DataFrame (data, columns = ['neighborhood','scooters','pop density (/km^2)', 'SCR', 'Postal Code','latitude', 'longitude'], 
                   index=['0','1','2','3','4','5']
                  )
table1
# Out:
#               neighborhood scooters pop density (/km^2)     SCR Postal Code  \
# 0            Downtown West   105251               2,900  46.914       55404
# 1             Marcy Holmes    67993               4,700  19.407       55414
# 2  University of Minnesota    52720               3,100  21.549       55455
# 3          Cedar Riverside    41160               5,700   9.243       55454
# 4               North Loop    39465               2,000  24.526       55405
# 5            Prospect Park    26602               2,300  16.055       55414
#
#              latitude           longitude
# 0         44.96109575       -93.255894125
# 1         44.98711935        -93.24115775
# 2   44.97473309462231  -93.23407422863205
# 3          44.9676909  -93.23853524743203
# 4  44.957127150000005  -93.30278685186671
# 5             44.9710            -93.2153

# %% [markdown]
# The highest SCR for each neighborhood in descending order is:
# 1. Downtown West (46.914)
# 2. North Loop (24.526)
# 3. University of_Minnesota (21.549)
# 4. Marcy Holmes (19.407)
# 5. Prospect Park (16.055)
# 6. Cedar Riverside (9.243)

# %% [markdown]
# ## List of key locations
#
# Let's find the coordinates to some of Minneapolis' known high traffic areas so we can consider them when choosing which 3 neighborhoods to place scooter maintenance facilities.

# %%
address = '300 Washington Ave SE, Minneapolis, MN 55455'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of central Univeristy of Minnesota {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of central Univeristy of Minnesota 44.97377352390003, -93.23580432404897.

# %%
address = '3001 Hennepin Ave, Minneapolis, MN 55408'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Calhoun Square {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Calhoun Square 44.9771885, -93.2759196.

# %%
address = '4825 Minnehaha Ave, Minneapolis, MN 55417'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Minnehaha Falls {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Minnehaha Falls 44.91502861590828, -93.20671585069111.

# %%
address = '300 South 6th St, Minneapolis, MN 55487'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Central Downtown Minneapolis {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Downtown Minneapolis 44.97586835, -93.26664821257543.

# %% [markdown]
# ## Finding average distance
#
# Now let's find the average total distance that each of the most congested neighborhoods (shown above) is from each of our key transit locations. These are locations where high commuter traffick is known. After finding these distances we will organize each neighborhood in a table from lowest average distance to heighest. This table will then be a deciding factor in which neighborhood to place a maintenance facility.

# %%
# Create two dataframes with city names and lat-long in degrees
table2 = pd.DataFrame({
    'neighborhood' :     ['Downtown West','Marcy Holmes','University','Cedar Riverside','North Loop','Prospect Park'],
    'latitude':  [ 44.96109575, 44.98711935, 44.97473309462231, 44.9676909, 44.957127150000005, 44.9710],
    'longitude': [ -93.255894125, -93.24115775, -93.23407422863205, -93.23853524743203, -93.30278685186671, -93.2153]
})
table3 = pd.DataFrame({
    'location':      ['University of Minnesota','Calhoun Square','Minnehaha Falls','Central Downtown Minneapolis'],
    'latitude_B' : [ 44.97377352390003, 44.9771885, 44.91502861590828,44.97586835],
    'longitude_B': [ -93.23580432404897, -93.2759196, -93.20671585069111,-93.26664821257543]
})

# %%
# add columns with radians for latitude and longitude
table2[['lat_radians','long_radians']] = (
    np.radians(table2.loc[:,['latitude','longitude']])
)
table3[['lat_radians_B','long_radians_B']] = (
    np.radians(table3.loc[:,['latitude_B','longitude_B']])
)

# %%
table2
# Out:
#       neighborhood   latitude  longitude  lat_radians  long_radians
# 0    Downtown West  44.961096 -93.255894     0.784719     -1.627622
# 1     Marcy Holmes  44.987119 -93.241158     0.785173     -1.627365
# 2       University  44.974733 -93.234074     0.784957     -1.627242
# 3  Cedar Riverside  44.967691 -93.238535     0.784834     -1.627319
# 4       North Loop  44.957127 -93.302787     0.784650     -1.628441
# 5    Prospect Park  44.971000 -93.215300     0.784892     -1.626914

# %%
table3
# Out:
#                        location  latitude_B  longitude_B  lat_radians_B  \
# 0       University of Minnesota   44.973774   -93.235804       0.784940
# 1                Calhoun Square   44.977188   -93.275920       0.785000
# 2               Minnehaha Falls   44.915029   -93.206716       0.783915
# 3  Central Downtown Minneapolis   44.975868   -93.266648       0.784977
#
#    long_radians_B
# 0       -1.627272
# 1       -1.627972
# 2       -1.626764
# 3       -1.627810

# %% [markdown]
# Find distance between neighborhood and key location measured in miles. We will use the library __sklearn__ to use the 'haversine' distance, which assumes the world is a true sphere with a radius equal to 1. This makes computation easy and doesn't include the 3rd dimension of height when calculating a distance between two coordinates. To get the distance in miles we muliply the output of the sklearn computation by 3959 miles (the average radius of the earth). To get the distance in Km we could use a number of 6371.

# %%
dist = sklearn.neighbors.DistanceMetric.get_metric('haversine')
dist_matrix = (dist.pairwise
    (table2[['lat_radians','long_radians']],
     table3[['lat_radians_B','long_radians_B']])*3959
)
# Note that 3959 is the radius of the earth in miles
df_dist_matrix = (
    pd.DataFrame(dist_matrix,index=table2['neighborhood'], 
                 columns=table3['location'])
)

# %%
df_dist_matrix
# Out:
# location         University of Minnesota  Calhoun Square  Minnehaha Falls  \
# neighborhood
# Downtown West                   1.316042        1.481499         3.989778
# Marcy Holmes                    0.958567        1.832313         5.258326
# University                      0.107463        2.052421         4.336987
# Cedar Riverside                 0.440987        1.941718         3.957663
# North Loop                      3.470829        1.909640         5.526684
# Prospect Park                   1.020468        2.993869         3.890208
#
# location         Central Downtown Minneapolis
# neighborhood
# Downtown West                        1.148182
# Marcy Holmes                         1.468509
# University                           1.594161
# Cedar Riverside                      1.485886
# North Loop                           2.190510
# Prospect Park                        2.532446

# %%
df_dist_matrix['average'] = df_dist_matrix.mean(numeric_only=True, axis=1)
df_dist_matrix
# Out:
# location         University of Minnesota  Calhoun Square  Minnehaha Falls  \
# neighborhood
# Downtown West                   1.316042        1.481499         3.989778
# Marcy Holmes                    0.958567        1.832313         5.258326
# University                      0.107463        2.052421         4.336987
# Cedar Riverside                 0.440987        1.941718         3.957663
# North Loop                      3.470829        1.909640         5.526684
# Prospect Park                   1.020468        2.993869         3.890208
#
# location         Central Downtown Minneapolis   average
# neighborhood
# Downtown West                        1.148182  1.983875
# Marcy Holmes                         1.468509  2.379429
# University                           1.594161  2.022758
# Cedar Riverside                      1.485886  1.956564
# North Loop                           2.190510  3.274416
# Prospect Park                        2.532446  2.609248

# %%
table4 = df_dist_matrix.sort_values(by=['average'], ascending=True)
table4
# Out:
# location         University of Minnesota  Calhoun Square  Minnehaha Falls  \
# neighborhood
# Cedar Riverside                 0.440987        1.941718         3.957663
# Downtown West                   1.316042        1.481499         3.989778
# University                      0.107463        2.052421         4.336987
# Marcy Holmes                    0.958567        1.832313         5.258326
# Prospect Park                   1.020468        2.993869         3.890208
# North Loop                      3.470829        1.909640         5.526684
#
# location         Central Downtown Minneapolis   average
# neighborhood
# Cedar Riverside                      1.485886  1.956564
# Downtown West                        1.148182  1.983875
# University                           1.594161  2.022758
# Marcy Holmes                         1.468509  2.379429
# Prospect Park                        2.532446  2.609248
# North Loop                           2.190510  3.274416

# %% [markdown]
# From the table above in the 'average' column we see the nearest neighborhood to our key locations is Cedar Riverside. The next nearest neighborhood to all key locations is Downtown West. We can use this information later when deciding which neighborhoods to install the maintenance faciltiies.

# %% [markdown]
# ## Using FourSquare API

# %% [markdown]
# In this section we will explore the number of transit centers within each neighborhood using the __FourSquare API__. Building a scooter maintenance facility next to or within a transit center is a priority because commuters will be able to conveniently connect to busess, trains, etc.
#
# Since Cedar Riverside is the nearest neighborhood to all key locations (as shown above), we chose this neighborhood as our center point for using the FourSquare API. Next we defined FourSqure to look for assets containing "transit center," and that are within x amount of radial meters from our center point.

# %%
# Define my FourSquare credentials and version.
# Note that with a free account we are limited to a maximum of 50 calls (limit = 50). 

CLIENT_ID = 'EAJJX1MODHA1XCGUIZ5VRU4BU04XAN0DW0BCPE1RM2EBMQVW' # your Foursquare ID
CLIENT_SECRET = 'LDJRGGX2DZWOWBCUUU2M4CKKWLXXAGDCD2RL20SUFUWI2SOI' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EAJJX1MODHA1XCGUIZ5VRU4BU04XAN0DW0BCPE1RM2EBMQVW
# CLIENT_SECRET:LDJRGGX2DZWOWBCUUU2M4CKKWLXXAGDCD2RL20SUFUWI2SOI

# %%
# define search. Radius in meters. Latitude & longitude are the location of Cedar Riverside neighborhood.
search_query = 'Transit Center'
radius = 8000
print(search_query + ' .... OK!')

latitude = 44.967691
longitude = -93.238535
# Out:
# Transit Center .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EAJJX1MODHA1XCGUIZ5VRU4BU04XAN0DW0BCPE1RM2EBMQVW&client_secret=LDJRGGX2DZWOWBCUUU2M4CKKWLXXAGDCD2RL20SUFUWI2SOI&ll=44.967691,-93.238535&v=20180604&query=Transit Center&radius=8000&limit=50'

# %%
# call FourSquare API to display results based on search query above
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fa56b96f0d3381728e72816'},
#  'response': {'venues': [{'id': '4bf29a70a32e20a1f261d557',
#     'name': 'Rosedale Transit Center',
#     'location': {'address': '10 Rosedale Ctr',
#      'lat': 45.012738055886814,
#      'lng': -93.16888077269982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.012738055886814,
#        'lng': -93.16888077269982}],
#      'distance': 7430,
#      'postalCode': '55113',
#      'cc': 'US',
#      'city': 'Roseville',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['10 Rosedale Ctr',
#       'Roseville, MN 55113',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b5c9cdaf964a520e83929e3',
#     'name': 'Fairview Transitional Center',
#     'location': {'address': '2512 S 7th St',
#      'lat': 44.967044830322266,
#      'lng': -93.23533630371094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.967044830322266,
#        'lng': -93.23533630371094}],
#      'distance': 261,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2512 S 7th St',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '50170b1fe4b0c3d592d66512',
#     'name': '5th Street North Transit Center',
#     'location': {'lat': 44.98084329574028,
#      'lng': -93.27512763149889,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.98084329574028,
#        'lng': -93.27512763149889}],
#      'distance': 3232,
#      'postalCode': '55403',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN 55403', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4d9ce4957865a0934ea3db7a',
#     'name': 'Ramp B/ 5th St Transit Center',
#     'location': {'address': '516 2nd Ave N',
#      'crossStreet': 'I-394',
#      'lat': 44.98150713161008,
#      'lng': -93.27589817690189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.98150713161008,
#        'lng': -93.27589817690189},
#       {'label': 'entrance', 'lat': 44.980742, 'lng': -93.275162}],
#      'distance': 3320,
#      'postalCode': '55403',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['516 2nd Ave N (I-394)',
#       'Minneapolis, MN 55403',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4dfa968b149557de37aaa336',
#     'name': 'Columbia Heights Transit Center',
#     'location': {'address': '4079 Central Ave NE',
#      'lat': 45.04241675562383,
#      'lng': -93.24694446564094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.04241675562383,
#        'lng': -93.24694446564094}],
#      'distance': 8344,
#      'postalCode': '55421',
#      'cc': 'US',
#      'city': 'Columbia Heights',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['4079 Central Ave NE',
#       'Columbia Heights, MN 55421',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4f53fb16e4b0e14ed8ba6f83',
#     'name': "Veteran's Transition Center",
#     'location': {'address': '101 Pleasant St SE, University of Minnesota - Minneapolis, Minneapolis, MN 55455',
#      'lat': 44.9758205822622,
#      'lng': -93.23644700989178,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.9758205822622,
#        'lng': -93.23644700989178}],
#      'distance': 919,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['101 Pleasant St SE, University of Minnesota - Minneapolis, Minneapolis, MN 55455',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '57ce4e3e498e532c6b0e8a7a',
#     'name': 'MN State Fair Main Gate Transit Center',
#     'location': {'lat': 44.980698,
#      'lng': -93.16509,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.980698,
#        'lng': -93.16509}],
#      'distance': 5962,
#      'postalCode': '55108',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Saint Paul, MN 55108', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4aae58a9f964a520e36120e3',
#     'name': 'University of Minnesota Medical Center, Fairview - West Bank',
#     'location': {'address': '2450 Riverside Ave',
#      'lat': 44.96775643983586,
#      'lng': -93.2381354200481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96775643983586,
#        'lng': -93.2381354200481}],
#      'distance': 32,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2450 Riverside Ave',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4c96aa63bc279c7433bf6853',
#     'name': 'U of M-Fairview Riverside- professional Center',
#     'location': {'address': '606 24th Ave S',
#      'crossStreet': 'Riverside',
#      'lat': 44.96723199690378,
#      'lng': -93.23810794395284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96723199690378,
#        'lng': -93.23810794395284}],
#      'distance': 61,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['606 24th Ave S (Riverside)',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4bdf2269e75c0f47edffc903',
#     'name': 'Maternal-Fetal Medicine Center',
#     'location': {'address': '606 24th Ave S Ste 400',
#      'lat': 44.96712875366211,
#      'lng': -93.23806762695312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96712875366211,
#        'lng': -93.23806762695312}],
#      'distance': 72,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['606 24th Ave S Ste 400',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4c3e26da80bc20a1c99caa58',
#     'name': 'Gateway Transit Station',
#     'location': {'address': '3rd St',
#      'crossStreet': '5th Ave',
#      'lat': 44.97901980661695,
#      'lng': -93.26152035665801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97901980661695,
#        'lng': -93.26152035665801}],
#      'distance': 2206,
#      'postalCode': '55415',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['3rd St (5th Ave)',
#       'Minneapolis, MN 55415',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b10955ff964a520457323e3',
#     'name': 'Chicago-Lake Transit Station',
#     'location': {'address': '2950 Chicago Ave S',
#      'crossStreet': 'btw Lake & 29th St',
#      'lat': 44.949675997655916,
#      'lng': -93.26259202940754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.949675997655916,
#        'lng': -93.26259202940754}],
#      'distance': 2759,
#      'postalCode': '55407',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2950 Chicago Ave S (btw Lake & 29th St)',
#       'Minneapolis, MN 55407',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4ba943b2f964a5206e193ae3',
#     'name': 'Willey Hall Metro Transit Stop',
#     'location': {'address': '225 19th Ave S',
#      'lat': 44.97259754792726,
#      'lng': -93.24341408093802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97259754792726,
#        'lng': -93.24341408093802}],
#      'distance': 667,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['225 19th Ave S',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4acd318af964a52055cb20e3',
#     'name': 'Uptown Transit Station',
#     'location': {'address': '2860 Hennepin Ave S',
#      'crossStreet': 'at W 29th St',
#      'lat': 44.950196278356586,
#      'lng': -93.29841478660713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.950196278356586,
#        'lng': -93.29841478660713}],
#      'distance': 5103,
#      'postalCode': '55408',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2860 Hennepin Ave S (at W 29th St)',
#       'Minneapolis, MN 55408',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4e043196a8090c0936a03e44',
#     'name': 'U of M Medical Center Ramp',
#     'location': {'address': '615 Delaware St. SE',
#      'crossStreet': 'btw Harvard & Walnut',
#      'lat': 44.97271001054783,
#      'lng': -93.22935603847668,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97271001054783,
#        'lng': -93.22935603847668}],
#      'distance': 913,
#      'postalCode': '55414',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['615 Delaware St. SE (btw Harvard & Walnut)',
#       'Minneapolis, MN 55414',
#       'United States']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '56d870cacd1091991e2f15ca',
#     'name': 'University of Minnesota Health Clinics and Surgery Center',
#     'location': {'address': '909 Fulton St SE',
#      'lat': 44.970840055946965,
#      'lng': -93.22519969407506,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.970840055946965,
#        'lng': -93.22519969407506},
#       {'label': 'entrance', 'lat': 44.970899, 'lng': -93.225362}],
#      'distance': 1107,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['909 Fulton St SE',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '380435325'},
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4d5c36982a31a1cd7d7345f1',
#     'name': "Children's Rehabilitation Center",
#     'location': {'address': '426 Church St SE',
#      'crossStreet': 'at University Of Minnesota',
#      'lat': 44.971556,
#      'lng': -93.234086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.971556,
#        'lng': -93.234086},
#       {'label': 'entrance', 'lat': 44.971589, 'lng': -93.233926}],
#      'distance': 554,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['426 Church St SE (at University Of Minnesota)',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b171467f964a520f7c123e3',
#     'name': 'Kennedy Center: James Haglund Family Fitness and Recreation Center',
#     'location': {'address': '715 23rd Ave S',
#      'lat': 44.965578899921695,
#      'lng': -93.23919106656341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.965578899921695,
#        'lng': -93.23919106656341}],
#      'distance': 240,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['715 23rd Ave S',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4bb3b4c7715eef3bafb986bb',
#     'name': 'University of Minnesota Medical Center, Fairview - East Bank',
#     'location': {'address': '500 Harvard St SE',
#      'lat': 44.97136109368744,
#      'lng': -93.23073929185031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97136109368744,
#        'lng': -93.23073929185031}],
#      'distance': 737,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['500 Harvard St SE',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '510d90b3e4b05ed0e43ed6cc',
#     'name': 'Gage Center - Augsburg College',
#     'location': {'address': 'Lindell Library, Second Floor',
#      'crossStreet': '(Link Level)',
#      'lat': 44.96663401614048,
#      'lng': -93.24174749351587,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96663401614048,
#        'lng': -93.24174749351587}],
#      'distance': 279,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Lindell Library, Second Floor ((Link Level))',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '571f7646498e55adb3ce1539',
#     'name': 'University of Minnesota Health Clinics and Surgery Center - Masonic Cancer Clinic',
#     'location': {'address': '909 fulton St SE, 2nd Floor',
#      'lat': 44.97089358371693,
#      'lng': -93.22475388661657,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97089358371693,
#        'lng': -93.22475388661657}],
#      'distance': 1142,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['909 fulton St SE, 2nd Floor',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '375935070'},
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4be80d779a54a593f5750911',
#     'name': 'University of Minnesota Medical Center Orthopedics',
#     'location': {'address': '2512 S 7th St',
#      'lat': 44.966692030000004,
#      'lng': -93.235579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.966692030000004,
#        'lng': -93.235579}],
#      'distance': 258,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2512 S 7th St',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '45c36c58f964a52037421fe3',
#     'name': 'McNamara Alumni Center',
#     'location': {'address': '200 Oak St. SE',
#      'crossStreet': 'at University Ave.',
#      'lat': 44.97538489999999,
#      'lng': -93.22760269999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97538489999999,
#        'lng': -93.22760269999999}],
#      'distance': 1214,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['200 Oak St. SE (at University Ave.)',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d100941735',
#       'name': 'Meeting Room',
#       'pluralName': 'Meeting Rooms',
#       'shortName': 'Meeting Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_meetingroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4abb6f44f964a520be8320e3',
#     'name': 'Masonic Cancer Center Research Building',
#     'location': {'address': '425 E River Pkwy',
#      'lat': 44.97090761142121,
#      'lng': -93.23258824601899,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97090761142121,
#        'lng': -93.23258824601899}],
#      'distance': 589,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['425 E River Pkwy',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b87ff3df964a520b3d731e3',
#     'name': 'Christensen Center Student Art Gallery',
#     'location': {'address': 'Main Floor, Christensen Center',
#      'crossStreet': '22nd Ave. S. at 7 1/2 Street',
#      'lat': 44.96598720300629,
#      'lng': -93.24094502921226,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96598720300629,
#        'lng': -93.24094502921226}],
#      'distance': 268,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Main Floor, Christensen Center (22nd Ave. S. at 7 1/2 Street)',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b7f1a63f964a520a51630e3',
#     'name': 'Metro Transit Bus #16',
#     'location': {'lat': 44.96798573507858,
#      'lng': -93.21565880315136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96798573507858,
#        'lng': -93.21565880315136}],
#      'distance': 1801,
#      'postalCode': '55114',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Saint Paul, MN 55114', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4e8a1b80be7bd98872ac217c',
#     'name': 'Transit Stop C 460 Express',
#     'location': {'lat': 44.97626953333334,
#      'lng': -93.27102058333334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97626953333334,
#        'lng': -93.27102058333334}],
#      'distance': 2730,
#      'postalCode': '55402',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN 55402', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '51e71362498e2ce95fcc6f6b',
#     'name': 'Transit for Livable Communities',
#     'location': {'address': '2356 University Ave W',
#      'lat': 44.9631790100192,
#      'lng': -93.19717500544125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.9631790100192,
#        'lng': -93.19717500544125}],
#      'distance': 3296,
#      'postalCode': '55114',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2356 University Ave W',
#       'Saint Paul, MN 55114',
#       'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '500f2242e4b00fee85cf27c5',
#     'name': 'Metro Transit Wellness Center Stop',
#     'location': {'lat': 44.97816284161655,
#      'lng': -93.22989552332348,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97816284161655,
#        'lng': -93.22989552332348}],
#      'distance': 1349,
#      'postalCode': '55414',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN 55414', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4cf3d07588de3704ea37812b',
#     'name': 'Metro Transit - Emerald St Westbound',
#     'location': {'address': 'University',
#      'crossStreet': 'Emerald',
#      'lat': 44.96839487552816,
#      'lng': -93.20823711241198,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96839487552816,
#        'lng': -93.20823711241198}],
#      'distance': 2387,
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['University (Emerald)',
#       'Saint Paul, MN',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4a3de49cf964a520bda21fe3',
#     'name': 'Hennepin County Medical Center (HCMC)',
#     'location': {'address': '701 Park Ave',
#      'lat': 44.97209679482329,
#      'lng': -93.26180127775605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97209679482329,
#        'lng': -93.26180127775605},
#       {'label': 'entrance', 'lat': 44.9723, 'lng': -93.262949}],
#      'distance': 1896,
#      'postalCode': '55415',
#      'cc': 'US',
#      'neighborhood': 'Elliot Park',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['701 Park Ave',
#       'Minneapolis, MN 55415',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4bb38b2242959c743e16222c',
#     'name': 'Metro Transit Bus #50',
#     'location': {'lat': 44.968617143652416,
#      'lng': -93.21470901510648,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.968617143652416,
#        'lng': -93.21470901510648}],
#      'distance': 1879,
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b1951d7f964a5202fdb23e3',
#     'name': 'Ameriprise Client Service Center',
#     'location': {'address': '901 3rd Ave S',
#      'crossStreet': 'S 9th St',
#      'lat': 44.972533990728586,
#      'lng': -93.27018649971218,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.972533990728586,
#        'lng': -93.27018649971218}],
#      'distance': 2550,
#      'postalCode': '55402',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['901 3rd Ave S (S 9th St)',
#       'Minneapolis, MN 55402',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4d5069d7d7eaa1432b96670f',
#     'name': 'Metro Transit Bus #2',
#     'location': {'address': '4th St SE',
#      'crossStreet': '19th Ave',
#      'lat': 44.964714698989354,
#      'lng': -93.236017333292,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.964714698989354,
#        'lng': -93.236017333292}],
#      'distance': 386,
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['4th St SE (19th Ave)',
#       'Minneapolis, MN',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4dd1a136c65b9d071f8a64f7',
#     'name': 'Metro Transit #59',
#     'location': {'lat': 44.9810054028316,
#      'lng': -93.26856446570063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.9810054028316,
#        'lng': -93.26856446570063}],
#      'distance': 2790,
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4c6bece77c052d7f05882acf',
#     'name': 'Government Center Municipal Parking Ramp',
#     'location': {'address': '415 S 5th St',
#      'crossStreet': '6th Avenue',
#      'lat': 44.97560601601516,
#      'lng': -93.26556484040673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97560601601516,
#        'lng': -93.26556484040673},
#       {'label': 'entrance', 'lat': 44.976046, 'lng': -93.264344}],
#      'distance': 2303,
#      'postalCode': '55415',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['415 S 5th St (6th Avenue)',
#       'Minneapolis, MN 55415',
#       'United States']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b709c20f964a52017252de3',
#     'name': 'Metro Transit Fred T. Heywood Office Building and Garage - HQ, Lost & Found, Customer Service',
#     'location': {'address': '570 6th Ave N',
#      'lat': 44.98475587350371,
#      'lng': -93.28199704939068,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.98475587350371,
#        'lng': -93.28199704939068},
#       {'label': 'entrance', 'lat': 44.98461, 'lng': -93.283132}],
#      'distance': 3914,
#      'postalCode': '55411',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['570 6th Ave N',
#       'Minneapolis, MN 55411',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4a721be2f964a5205fda1fe3',
#     'name': 'Rarig Center',
#     'location': {'address': '330 21st Ave S',
#      'crossStreet': 'at 21st Ave. S',
#      'lat': 44.97026630861508,
#      'lng': -93.24231832901405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97026630861508,
#        'lng': -93.24231832901405},
#       {'label': 'entrance', 'lat': 44.97034, 'lng': -93.242082}],
#      'distance': 413,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['330 21st Ave S (at 21st Ave. S)',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d137941735',
#       'name': 'Theater',
#       'pluralName': 'Theaters',
#       'shortName': 'Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b165dbbf964a52077b823e3',
#     'name': 'University Recreation and Wellness Center',
#     'location': {'address': '1906 SE University Ave',
#      'crossStreet': 'at Walnut St SE',
#      'lat': 44.97514996368085,
#      'lng': -93.22955374720318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97514996368085,
#        'lng': -93.22955374720318}],
#      'distance': 1090,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1906 SE University Ave (at Walnut St SE)',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a9941735',
#       'name': 'College Rec Center',
#       'pluralName': 'College Rec Centers',
#       'shortName': 'Rec Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/reccenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4bbb96582d9ea593ec989fce',
#     'name': 'City Center',
#     'location': {'address': '33 S 6th St',
#      'lat': 44.97762774903032,
#      'lng': -93.27235711093061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97762774903032,
#        'lng': -93.27235711093061}],
#      'distance': 2884,
#      'postalCode': '55402',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['33 S 6th St',
#       'Minneapolis, MN 55402',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4eaaae0df9f45048e72fe695',
#     'name': "Peoples's Center Gym",
#     'location': {'address': '425 20th Ave S',
#      'lat': 44.96915817260742,
#      'lng': -93.24378967285156,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 44.969216,
#        'lng': -93.243924},
#       {'label': 'display',
#        'lat': 44.96915817260742,
#        'lng': -93.24378967285156}],
#      'distance': 444,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['425 20th Ave S',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4a8452eef964a52045fc1fe3',
#     'name': 'IDS Center',
#     'location': {'address': '80 S 8th St',
#      'crossStreet': 'at Nicollet',
#      'lat': 44.97622542813549,
#      'lng': -93.27196177563641,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97622542813549,
#        'lng': -93.27196177563641},
#       {'label': 'entrance', 'lat': 44.97582, 'lng': -93.272455}],
#      'distance': 2798,
#      'postalCode': '55402',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['80 S 8th St (at Nicollet)',
#       'Minneapolis, MN 55402',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4a8af647f964a520030b20e3',
#     'name': 'Hennepin County Government Center',
#     'location': {'address': '300 S 6th St',
#      'crossStreet': 'btwn 3rd & 4th Ave S',
#      'lat': 44.97595608116425,
#      'lng': -93.2667654328865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97595608116425,
#        'lng': -93.2667654328865},
#       {'label': 'entrance', 'lat': 44.976863, 'lng': -93.266079}],
#      'distance': 2406,
#      'postalCode': '55487',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['300 S 6th St (btwn 3rd & 4th Ave S)',
#       'Minneapolis, MN 55487',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '50fc8a38e4b0d0487551ea6e',
#     'name': 'Blue Line Light Rail Operations & Maintenance Facility',
#     'location': {'address': '1810 E Franklin Ave',
#      'lat': 44.96377848417234,
#      'lng': -93.24946069540329,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.96377848417234,
#        'lng': -93.24946069540329}],
#      'distance': 964,
#      'postalCode': '55404',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1810 E Franklin Ave',
#       'Minneapolis, MN 55404',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'shortName': 'Light Rail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b89eaecf964a5201a5632e3',
#     'name': 'Metropolitan Transit Police Headquarters',
#     'location': {'address': '2425 Minnehaha Ave',
#      'lat': 44.958359348195124,
#      'lng': -93.24095541352112,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.958359348195124,
#        'lng': -93.24095541352112},
#       {'label': 'entrance', 'lat': 44.958028, 'lng': -93.240783}],
#      'distance': 1056,
#      'postalCode': '55404',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2425 Minnehaha Ave',
#       'Minneapolis, MN 55404',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'shortName': 'Police Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b54a819f964a52031c527e3',
#     'name': 'Coffman Union Transit Hub',
#     'location': {'address': 'Coffman Memorial Union',
#      'lat': 44.973614452995896,
#      'lng': -93.23516619861074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.973614452995896,
#        'lng': -93.23516619861074}],
#      'distance': 710,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Coffman Memorial Union',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4ca038f354c8a1cd31f59d4b',
#     'name': 'Metro Transit Control Center',
#     'location': {'lat': 44.98675724974185,
#      'lng': -93.28537014188751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.98675724974185,
#        'lng': -93.28537014188751}],
#      'distance': 4255,
#      'postalCode': '55411',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN 55411', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f6931735',
#       'name': 'General Travel',
#       'pluralName': 'General Travel',
#       'shortName': 'Travel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4c3caf807d00d13a48423950',
#     'name': 'HealthPartners Health Center for Women Clinic St. Paul',
#     'location': {'address': '2635 University Ave W,Suite 160',
#      'lat': 44.968201,
#      'lng': -93.205675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.968201,
#        'lng': -93.205675},
#       {'label': 'entrance', 'lat': 44.967387, 'lng': -93.20532}],
#      'distance': 2588,
#      'postalCode': '55114',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2635 University Ave W,Suite 160',
#       'Saint Paul, MN 55114',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '49ff1ed9f964a520cf6f1fe3',
#     'name': 'Nolte Center For Continuing Education',
#     'location': {'address': '315 Pillsbury Dr SE',
#      'crossStreet': 'at Church',
#      'lat': 44.97727038227756,
#      'lng': -93.23416056827104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97727038227756,
#        'lng': -93.23416056827104},
#       {'label': 'entrance', 'lat': 44.977248, 'lng': -93.233996}],
#      'distance': 1120,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['315 Pillsbury Dr SE (at Church)',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False},
#    {'id': '4b007aa2f964a520b63e22e3',
#     'name': 'University Aquatic Center',
#     'location': {'address': '1910 University Ave SE',
#      'lat': 44.975587655883565,
#      'lng': -93.22928963720878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.975587655883565,
#        'lng': -93.22928963720878}],
#      'distance': 1141,
#      'postalCode': '55455',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1910 University Ave SE',
#       'Minneapolis, MN 55455',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a9941735',
#       'name': 'College Rec Center',
#       'pluralName': 'College Rec Centers',
#       'shortName': 'Rec Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/reccenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604676502',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  4bf29a70a32e20a1f261d557          Rosedale Transit Center
# 1  4b5c9cdaf964a520e83929e3     Fairview Transitional Center
# 2  50170b1fe4b0c3d592d66512  5th Street North Transit Center
# 3  4d9ce4957865a0934ea3db7a    Ramp B/ 5th St Transit Center
# 4  4dfa968b149557de37aaa336  Columbia Heights Transit Center
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...  v-1604676502    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1604676502    False
# 2  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...  v-1604676502    False
# 3  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...  v-1604676502    False
# 4  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...  v-1604676502    False
#
#       location.address  location.lat  location.lng  \
# 0      10 Rosedale Ctr     45.012738    -93.168881
# 1        2512 S 7th St     44.967045    -93.235336
# 2                  NaN     44.980843    -93.275128
# 3        516 2nd Ave N     44.981507    -93.275898
# 4  4079 Central Ave NE     45.042417    -93.246944
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 45.01273805588681...               7430
# 1  [{'label': 'display', 'lat': 44.96704483032226...                261
# 2  [{'label': 'display', 'lat': 44.98084329574028...               3232
# 3  [{'label': 'display', 'lat': 44.98150713161008...               3320
# 4  [{'label': 'display', 'lat': 45.04241675562383...               8344
#
#   location.postalCode location.cc     location.city location.state  \
# 0               55113          US         Roseville             MN
# 1               55454          US       Minneapolis             MN
# 2               55403          US       Minneapolis             MN
# 3               55403          US       Minneapolis             MN
# 4               55421          US  Columbia Heights             MN
#
#   location.country                          location.formattedAddress  \
# 0    United States  [10 Rosedale Ctr, Roseville, MN 55113, United ...
# 1    United States  [2512 S 7th St, Minneapolis, MN 55454, United ...
# 2    United States             [Minneapolis, MN 55403, United States]
# 3    United States  [516 2nd Ave N (I-394), Minneapolis, MN 55403,...
# 4    United States  [4079 Central Ave NE, Columbia Heights, MN 554...
#
#   location.crossStreet venuePage.id location.neighborhood
# 0                  NaN          NaN                   NaN
# 1                  NaN          NaN                   NaN
# 2                  NaN          NaN                   NaN
# 3                I-394          NaN                   NaN
# 4                  NaN          NaN                   NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                             Rosedale Transit Center
# 1                        Fairview Transitional Center
# 2                     5th Street North Transit Center
# 3                       Ramp B/ 5th St Transit Center
# 4                     Columbia Heights Transit Center
# 5                         Veteran's Transition Center
# 6              MN State Fair Main Gate Transit Center
# 7   University of Minnesota Medical Center, Fairvi...
# 8      U of M-Fairview Riverside- professional Center
# 9                      Maternal-Fetal Medicine Center
# 10                            Gateway Transit Station
# 11                       Chicago-Lake Transit Station
# 12                     Willey Hall Metro Transit Stop
# 13                             Uptown Transit Station
# 14                         U of M Medical Center Ramp
# 15  University of Minnesota Health Clinics and Sur...
# 16                   Children's Rehabilitation Center
# 17  Kennedy Center: James Haglund Family Fitness a...
# 18  University of Minnesota Medical Center, Fairvi...
# 19                     Gage Center - Augsburg College
# 20  University of Minnesota Health Clinics and Sur...
# 21  University of Minnesota Medical Center Orthope...
# 22                             McNamara Alumni Center
# 23            Masonic Cancer Center Research Building
# 24             Christensen Center Student Art Gallery
# 25                              Metro Transit Bus #16
# 26                         Transit Stop C 460 Express
# 27                    Transit for Livable Communities
# 28                 Metro Transit Wellness Center Stop
# 29               Metro Transit - Emerald St Westbound
# 30              Hennepin County Medical Center (HCMC)
# 31                              Metro Transit Bus #50
# 32                   Ameriprise Client Service Center
# 33                               Metro Transit Bus #2
# 34                                  Metro Transit #59
# 35           Government Center Municipal Parking Ramp
# 36  Metro Transit Fred T. Heywood Office Building ...
# 37                                       Rarig Center
# 38          University Recreation and Wellness Center
# 39                                        City Center
# 40                               Peoples's Center Gym
# 41                                         IDS Center
# 42                  Hennepin County Government Center
# 43  Blue Line Light Rail Operations & Maintenance ...
# 44           Metropolitan Transit Police Headquarters
# 45                          Coffman Union Transit Hub
# 46                       Metro Transit Control Center
# 47  HealthPartners Health Center for Women Clinic ...
# 48              Nolte Center For Continuing Education
# 49                          University Aquatic Center
#
#                          categories  \
# 0                       Bus Station
# 1                          Hospital
# 2                       Bus Station
# 3                       Bus Station
# 4                       Bus Station
# 5                 College Classroom
# 6                       Bus Station
# 7                          Hospital
# 8                    Medical Center
# 9                   Doctor's Office
# 10                      Bus Station
# 11                      Bus Station
# 12                         Bus Line
# 13                      Bus Station
# 14                          Parking
# 15                   Medical Center
# 16  College Administrative Building
# 17                      College Gym
# 18                         Hospital
# 19                   Student Center
# 20                   Medical Center
# 21                  Doctor's Office
# 22                     Meeting Room
# 23                   Medical Center
# 24                      Art Gallery
# 25                         Bus Line
# 26                         Bus Line
# 27                       Non-Profit
# 28                      Bus Station
# 29                      Bus Station
# 30                         Hospital
# 31                         Bus Line
# 32                           Office
# 33                      Bus Station
# 34                         Bus Line
# 35                          Parking
# 36                           Office
# 37                          Theater
# 38               College Rec Center
# 39                         Building
# 40     General College & University
# 41                         Building
# 42              Government Building
# 43               Light Rail Station
# 44                   Police Station
# 45                         Bus Line
# 46                   General Travel
# 47                  Doctor's Office
# 48        College Academic Building
# 49               College Rec Center
#
#                                               address        lat        lng  \
# 0                                     10 Rosedale Ctr  45.012738 -93.168881
# 1                                       2512 S 7th St  44.967045 -93.235336
# 2                                                 NaN  44.980843 -93.275128
# 3                                       516 2nd Ave N  44.981507 -93.275898
# 4                                 4079 Central Ave NE  45.042417 -93.246944
# 5   101 Pleasant St SE, University of Minnesota - ...  44.975821 -93.236447
# 6                                                 NaN  44.980698 -93.165090
# 7                                  2450 Riverside Ave  44.967756 -93.238135
# 8                                      606 24th Ave S  44.967232 -93.238108
# 9                              606 24th Ave S Ste 400  44.967129 -93.238068
# 10                                             3rd St  44.979020 -93.261520
# 11                                 2950 Chicago Ave S  44.949676 -93.262592
# 12                                     225 19th Ave S  44.972598 -93.243414
# 13                                2860 Hennepin Ave S  44.950196 -93.298415
# 14                                615 Delaware St. SE  44.972710 -93.229356
# 15                                   909 Fulton St SE  44.970840 -93.225200
# 16                                   426 Church St SE  44.971556 -93.234086
# 17                                     715 23rd Ave S  44.965579 -93.239191
# 18                                  500 Harvard St SE  44.971361 -93.230739
# 19                      Lindell Library, Second Floor  44.966634 -93.241747
# 20                        909 fulton St SE, 2nd Floor  44.970894 -93.224754
# 21                                      2512 S 7th St  44.966692 -93.235579
# 22                                     200 Oak St. SE  44.975385 -93.227603
# 23                                   425 E River Pkwy  44.970908 -93.232588
# 24                     Main Floor, Christensen Center  44.965987 -93.240945
# 25                                                NaN  44.967986 -93.215659
# 26                                                NaN  44.976270 -93.271021
# 27                              2356 University Ave W  44.963179 -93.197175
# 28                                                NaN  44.978163 -93.229896
# 29                                         University  44.968395 -93.208237
# 30                                       701 Park Ave  44.972097 -93.261801
# 31                                                NaN  44.968617 -93.214709
# 32                                      901 3rd Ave S  44.972534 -93.270186
# 33                                          4th St SE  44.964715 -93.236017
# 34                                                NaN  44.981005 -93.268564
# 35                                       415 S 5th St  44.975606 -93.265565
# 36                                      570 6th Ave N  44.984756 -93.281997
# 37                                     330 21st Ave S  44.970266 -93.242318
# 38                             1906 SE University Ave  44.975150 -93.229554
# 39                                        33 S 6th St  44.977628 -93.272357
# 40                                     425 20th Ave S  44.969158 -93.243790
# 41                                        80 S 8th St  44.976225 -93.271962
# 42                                       300 S 6th St  44.975956 -93.266765
# 43                                1810 E Franklin Ave  44.963778 -93.249461
# 44                                 2425 Minnehaha Ave  44.958359 -93.240955
# 45                             Coffman Memorial Union  44.973614 -93.235166
# 46                                                NaN  44.986757 -93.285370
# 47                    2635 University Ave W,Suite 160  44.968201 -93.205675
# 48                                315 Pillsbury Dr SE  44.977270 -93.234161
# 49                             1910 University Ave SE  44.975588 -93.229290
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 45.01273805588681...      7430      55113
# 1   [{'label': 'display', 'lat': 44.96704483032226...       261      55454
# 2   [{'label': 'display', 'lat': 44.98084329574028...      3232      55403
# 3   [{'label': 'display', 'lat': 44.98150713161008...      3320      55403
# 4   [{'label': 'display', 'lat': 45.04241675562383...      8344      55421
# 5   [{'label': 'display', 'lat': 44.9758205822622,...       919      55455
# 6   [{'label': 'display', 'lat': 44.980698, 'lng':...      5962      55108
# 7   [{'label': 'display', 'lat': 44.96775643983586...        32      55454
# 8   [{'label': 'display', 'lat': 44.96723199690378...        61      55454
# 9   [{'label': 'display', 'lat': 44.96712875366211...        72      55454
# 10  [{'label': 'display', 'lat': 44.97901980661695...      2206      55415
# 11  [{'label': 'display', 'lat': 44.94967599765591...      2759      55407
# 12  [{'label': 'display', 'lat': 44.97259754792726...       667      55455
# 13  [{'label': 'display', 'lat': 44.95019627835658...      5103      55408
# 14  [{'label': 'display', 'lat': 44.97271001054783...       913      55414
# 15  [{'label': 'display', 'lat': 44.97084005594696...      1107      55455
# 16  [{'label': 'display', 'lat': 44.971556, 'lng':...       554      55455
# 17  [{'label': 'display', 'lat': 44.96557889992169...       240      55454
# 18  [{'label': 'display', 'lat': 44.97136109368744...       737      55455
# 19  [{'label': 'display', 'lat': 44.96663401614048...       279      55454
# 20  [{'label': 'display', 'lat': 44.97089358371693...      1142      55455
# 21  [{'label': 'display', 'lat': 44.96669203000000...       258      55454
# 22  [{'label': 'display', 'lat': 44.97538489999999...      1214      55455
# 23  [{'label': 'display', 'lat': 44.97090761142121...       589      55455
# 24  [{'label': 'display', 'lat': 44.96598720300629...       268      55454
# 25  [{'label': 'display', 'lat': 44.96798573507858...      1801      55114
# 26  [{'label': 'display', 'lat': 44.97626953333334...      2730      55402
# 27  [{'label': 'display', 'lat': 44.9631790100192,...      3296      55114
# 28  [{'label': 'display', 'lat': 44.97816284161655...      1349      55414
# 29  [{'label': 'display', 'lat': 44.96839487552816...      2387        NaN
# 30  [{'label': 'display', 'lat': 44.97209679482329...      1896      55415
# 31  [{'label': 'display', 'lat': 44.96861714365241...      1879        NaN
# 32  [{'label': 'display', 'lat': 44.97253399072858...      2550      55402
# 33  [{'label': 'display', 'lat': 44.96471469898935...       386        NaN
# 34  [{'label': 'display', 'lat': 44.9810054028316,...      2790        NaN
# 35  [{'label': 'display', 'lat': 44.97560601601516...      2303      55415
# 36  [{'label': 'display', 'lat': 44.98475587350371...      3914      55411
# 37  [{'label': 'display', 'lat': 44.97026630861508...       413      55455
# 38  [{'label': 'display', 'lat': 44.97514996368085...      1090      55455
# 39  [{'label': 'display', 'lat': 44.97762774903032...      2884      55402
# 40  [{'label': 'entrance', 'lat': 44.969216, 'lng'...       444      55454
# 41  [{'label': 'display', 'lat': 44.97622542813549...      2798      55402
# 42  [{'label': 'display', 'lat': 44.97595608116425...      2406      55487
# 43  [{'label': 'display', 'lat': 44.96377848417234...       964      55404
# 44  [{'label': 'display', 'lat': 44.95835934819512...      1056      55404
# 45  [{'label': 'display', 'lat': 44.97361445299589...       710      55455
# 46  [{'label': 'display', 'lat': 44.98675724974185...      4255      55411
# 47  [{'label': 'display', 'lat': 44.968201, 'lng':...      2588      55114
# 48  [{'label': 'display', 'lat': 44.97727038227756...      1120      55455
# 49  [{'label': 'display', 'lat': 44.97558765588356...      1141      55455
#
#     cc              city state        country  \
# 0   US         Roseville    MN  United States
# 1   US       Minneapolis    MN  United States
# 2   US       Minneapolis    MN  United States
# 3   US       Minneapolis    MN  United States
# 4   US  Columbia Heights    MN  United States
# 5   US       Minneapolis    MN  United States
# 6   US        Saint Paul    MN  United States
# 7   US       Minneapolis    MN  United States
# 8   US       Minneapolis    MN  United States
# 9   US       Minneapolis    MN  United States
# 10  US       Minneapolis    MN  United States
# 11  US       Minneapolis    MN  United States
# 12  US       Minneapolis    MN  United States
# 13  US       Minneapolis    MN  United States
# 14  US       Minneapolis    MN  United States
# 15  US       Minneapolis    MN  United States
# 16  US       Minneapolis    MN  United States
# 17  US       Minneapolis    MN  United States
# 18  US       Minneapolis    MN  United States
# 19  US       Minneapolis    MN  United States
# 20  US       Minneapolis    MN  United States
# 21  US       Minneapolis    MN  United States
# 22  US       Minneapolis    MN  United States
# 23  US       Minneapolis    MN  United States
# 24  US       Minneapolis    MN  United States
# 25  US        Saint Paul    MN  United States
# 26  US       Minneapolis    MN  United States
# 27  US        Saint Paul    MN  United States
# 28  US       Minneapolis    MN  United States
# 29  US        Saint Paul    MN  United States
# 30  US       Minneapolis    MN  United States
# 31  US       Minneapolis    MN  United States
# 32  US       Minneapolis    MN  United States
# 33  US       Minneapolis    MN  United States
# 34  US       Minneapolis    MN  United States
# 35  US       Minneapolis    MN  United States
# 36  US       Minneapolis    MN  United States
# 37  US       Minneapolis    MN  United States
# 38  US       Minneapolis    MN  United States
# 39  US       Minneapolis    MN  United States
# 40  US       Minneapolis    MN  United States
# 41  US       Minneapolis    MN  United States
# 42  US       Minneapolis    MN  United States
# 43  US       Minneapolis    MN  United States
# 44  US       Minneapolis    MN  United States
# 45  US       Minneapolis    MN  United States
# 46  US       Minneapolis    MN  United States
# 47  US        Saint Paul    MN  United States
# 48  US       Minneapolis    MN  United States
# 49  US       Minneapolis    MN  United States
#
#                                      formattedAddress  \
# 0   [10 Rosedale Ctr, Roseville, MN 55113, United ...
# 1   [2512 S 7th St, Minneapolis, MN 55454, United ...
# 2              [Minneapolis, MN 55403, United States]
# 3   [516 2nd Ave N (I-394), Minneapolis, MN 55403,...
# 4   [4079 Central Ave NE, Columbia Heights, MN 554...
# 5   [101 Pleasant St SE, University of Minnesota -...
# 6               [Saint Paul, MN 55108, United States]
# 7   [2450 Riverside Ave, Minneapolis, MN 55454, Un...
# 8   [606 24th Ave S (Riverside), Minneapolis, MN 5...
# 9   [606 24th Ave S Ste 400, Minneapolis, MN 55454...
# 10  [3rd St (5th Ave), Minneapolis, MN 55415, Unit...
# 11  [2950 Chicago Ave S (btw Lake & 29th St), Minn...
# 12  [225 19th Ave S, Minneapolis, MN 55455, United...
# 13  [2860 Hennepin Ave S (at W 29th St), Minneapol...
# 14  [615 Delaware St. SE (btw Harvard & Walnut), M...
# 15  [909 Fulton St SE, Minneapolis, MN 55455, Unit...
# 16  [426 Church St SE (at University Of Minnesota)...
# 17  [715 23rd Ave S, Minneapolis, MN 55454, United...
# 18  [500 Harvard St SE, Minneapolis, MN 55455, Uni...
# 19  [Lindell Library, Second Floor ((Link Level)),...
# 20  [909 fulton St SE, 2nd Floor, Minneapolis, MN ...
# 21  [2512 S 7th St, Minneapolis, MN 55454, United ...
# 22  [200 Oak St. SE (at University Ave.), Minneapo...
# 23  [425 E River Pkwy, Minneapolis, MN 55455, Unit...
# 24  [Main Floor, Christensen Center (22nd Ave. S. ...
# 25              [Saint Paul, MN 55114, United States]
# 26             [Minneapolis, MN 55402, United States]
# 27  [2356 University Ave W, Saint Paul, MN 55114, ...
# 28             [Minneapolis, MN 55414, United States]
# 29  [University (Emerald), Saint Paul, MN, United ...
# 30  [701 Park Ave, Minneapolis, MN 55415, United S...
# 31                   [Minneapolis, MN, United States]
# 32  [901 3rd Ave S (S 9th St), Minneapolis, MN 554...
# 33  [4th St SE (19th Ave), Minneapolis, MN, United...
# 34                   [Minneapolis, MN, United States]
# 35  [415 S 5th St (6th Avenue), Minneapolis, MN 55...
# 36  [570 6th Ave N, Minneapolis, MN 55411, United ...
# 37  [330 21st Ave S (at 21st Ave. S), Minneapolis,...
# 38  [1906 SE University Ave (at Walnut St SE), Min...
# 39  [33 S 6th St, Minneapolis, MN 55402, United St...
# 40  [425 20th Ave S, Minneapolis, MN 55454, United...
# 41  [80 S 8th St (at Nicollet), Minneapolis, MN 55...
# 42  [300 S 6th St (btwn 3rd & 4th Ave S), Minneapo...
# 43  [1810 E Franklin Ave, Minneapolis, MN 55404, U...
# 44  [2425 Minnehaha Ave, Minneapolis, MN 55404, Un...
# 45  [Coffman Memorial Union, Minneapolis, MN 55455...
# 46             [Minneapolis, MN 55411, United States]
# 47  [2635 University Ave W,Suite 160, Saint Paul, ...
# 48  [315 Pillsbury Dr SE (at Church), Minneapolis,...
# 49  [1910 University Ave SE, Minneapolis, MN 55455...
#
#                      crossStreet neighborhood                        id
# 0                            NaN          NaN  4bf29a70a32e20a1f261d557
# 1                            NaN          NaN  4b5c9cdaf964a520e83929e3
# 2                            NaN          NaN  50170b1fe4b0c3d592d66512
# 3                          I-394          NaN  4d9ce4957865a0934ea3db7a
# 4                            NaN          NaN  4dfa968b149557de37aaa336
# 5                            NaN          NaN  4f53fb16e4b0e14ed8ba6f83
# 6                            NaN          NaN  57ce4e3e498e532c6b0e8a7a
# 7                            NaN          NaN  4aae58a9f964a520e36120e3
# 8                      Riverside          NaN  4c96aa63bc279c7433bf6853
# 9                            NaN          NaN  4bdf2269e75c0f47edffc903
# 10                       5th Ave          NaN  4c3e26da80bc20a1c99caa58
# 11            btw Lake & 29th St          NaN  4b10955ff964a520457323e3
# 12                           NaN          NaN  4ba943b2f964a5206e193ae3
# 13                  at W 29th St          NaN  4acd318af964a52055cb20e3
# 14          btw Harvard & Walnut          NaN  4e043196a8090c0936a03e44
# 15                           NaN          NaN  56d870cacd1091991e2f15ca
# 16    at University Of Minnesota          NaN  4d5c36982a31a1cd7d7345f1
# 17                           NaN          NaN  4b171467f964a520f7c123e3
# 18                           NaN          NaN  4bb3b4c7715eef3bafb986bb
# 19                  (Link Level)          NaN  510d90b3e4b05ed0e43ed6cc
# 20                           NaN          NaN  571f7646498e55adb3ce1539
# 21                           NaN          NaN  4be80d779a54a593f5750911
# 22            at University Ave.          NaN  45c36c58f964a52037421fe3
# 23                           NaN          NaN  4abb6f44f964a520be8320e3
# 24  22nd Ave. S. at 7 1/2 Street          NaN  4b87ff3df964a520b3d731e3
# 25                           NaN          NaN  4b7f1a63f964a520a51630e3
# 26                           NaN          NaN  4e8a1b80be7bd98872ac217c
# 27                           NaN          NaN  51e71362498e2ce95fcc6f6b
# 28                           NaN          NaN  500f2242e4b00fee85cf27c5
# 29                       Emerald          NaN  4cf3d07588de3704ea37812b
# 30                           NaN  Elliot Park  4a3de49cf964a520bda21fe3
# 31                           NaN          NaN  4bb38b2242959c743e16222c
# 32                      S 9th St          NaN  4b1951d7f964a5202fdb23e3
# 33                      19th Ave          NaN  4d5069d7d7eaa1432b96670f
# 34                           NaN          NaN  4dd1a136c65b9d071f8a64f7
# 35                    6th Avenue          NaN  4c6bece77c052d7f05882acf
# 36                           NaN          NaN  4b709c20f964a52017252de3
# 37                at 21st Ave. S          NaN  4a721be2f964a5205fda1fe3
# 38               at Walnut St SE          NaN  4b165dbbf964a52077b823e3
# 39                           NaN          NaN  4bbb96582d9ea593ec989fce
# 40                           NaN          NaN  4eaaae0df9f45048e72fe695
# 41                   at Nicollet          NaN  4a8452eef964a52045fc1fe3
# 42          btwn 3rd & 4th Ave S          NaN  4a8af647f964a520030b20e3
# 43                           NaN          NaN  50fc8a38e4b0d0487551ea6e
# 44                           NaN          NaN  4b89eaecf964a5201a5632e3
# 45                           NaN          NaN  4b54a819f964a52031c527e3
# 46                           NaN          NaN  4ca038f354c8a1cd31f59d4b
# 47                           NaN          NaN  4c3caf807d00d13a48423950
# 48                     at Church          NaN  49ff1ed9f964a520cf6f1fe3
# 49                           NaN          NaN  4b007aa2f964a520b63e22e3

# %%
dataframe_filtered.name
# Out:
# 0                               Rosedale Transit Center
# 1                          Fairview Transitional Center
# 2                       5th Street North Transit Center
# 3                         Ramp B/ 5th St Transit Center
# 4                       Columbia Heights Transit Center
# 5                           Veteran's Transition Center
# 6                MN State Fair Main Gate Transit Center
# 7     University of Minnesota Medical Center, Fairvi...
# 8        U of M-Fairview Riverside- professional Center
# 9                        Maternal-Fetal Medicine Center
# 10                              Gateway Transit Station
# 11                         Chicago-Lake Transit Station
# 12                       Willey Hall Metro Transit Stop
# 13                               Uptown Transit Station
# 14                           U of M Medical Center Ramp
# 15    University of Minnesota Health Clinics and Sur...
# 16                     Children's Rehabilitation Center
# 17    Kennedy Center: James Haglund Family Fitness a...
# 18    University of Minnesota Medical Center, Fairvi...
# 19                       Gage Center - Augsburg College
# 20    University of Minnesota Health Clinics and Sur...
# 21    University of Minnesota Medical Center Orthope...
# 22                               McNamara Alumni Center
# 23              Masonic Cancer Center Research Building
# 24               Christensen Center Student Art Gallery
# 25                                Metro Transit Bus #16
# 26                           Transit Stop C 460 Express
# 27                      Transit for Livable Communities
# 28                   Metro Transit Wellness Center Stop
# 29                 Metro Transit - Emerald St Westbound
# 30                Hennepin County Medical Center (HCMC)
# 31                                Metro Transit Bus #50
# 32                     Ameriprise Client Service Center
# 33                                 Metro Transit Bus #2
# 34                                    Metro Transit #59
# 35             Government Center Municipal Parking Ramp
# 36    Metro Transit Fred T. Heywood Office Building ...
# 37                                         Rarig Center
# 38            University Recreation and Wellness Center
# 39                                          City Center
# 40                                 Peoples's Center Gym
# 41                                           IDS Center
# 42                    Hennepin County Government Center
# 43    Blue Line Light Rail Operations & Maintenance ...
# 44             Metropolitan Transit Police Headquarters
# 45                            Coffman Union Transit Hub
# 46                         Metro Transit Control Center
# 47    HealthPartners Health Center for Women Clinic ...
# 48                Nolte Center For Continuing Education
# 49                            University Aquatic Center
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around neighborhood

# add a red circle marker to represent the neighborhood
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# search query as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
n = len(dataframe_filtered.index)

print("Number of rows in table:", n)
# Out:
# Number of rows in table: 50

# %%
#To select rows whose column value equals a scalar, some_value, use ==:
df2 = dataframe_filtered.loc[dataframe_filtered['categories'] == 'Bus Station']
df2
# Out:
#                                       name   categories              address  \
# 0                  Rosedale Transit Center  Bus Station      10 Rosedale Ctr
# 2          5th Street North Transit Center  Bus Station                  NaN
# 3            Ramp B/ 5th St Transit Center  Bus Station        516 2nd Ave N
# 4          Columbia Heights Transit Center  Bus Station  4079 Central Ave NE
# 6   MN State Fair Main Gate Transit Center  Bus Station                  NaN
# 10                 Gateway Transit Station  Bus Station               3rd St
# 11            Chicago-Lake Transit Station  Bus Station   2950 Chicago Ave S
# 13                  Uptown Transit Station  Bus Station  2860 Hennepin Ave S
# 28      Metro Transit Wellness Center Stop  Bus Station                  NaN
# 29    Metro Transit - Emerald St Westbound  Bus Station           University
# 33                    Metro Transit Bus #2  Bus Station            4th St SE
#
#           lat        lng                                     labeledLatLngs  \
# 0   45.012738 -93.168881  [{'label': 'display', 'lat': 45.01273805588681...
# 2   44.980843 -93.275128  [{'label': 'display', 'lat': 44.98084329574028...
# 3   44.981507 -93.275898  [{'label': 'display', 'lat': 44.98150713161008...
# 4   45.042417 -93.246944  [{'label': 'display', 'lat': 45.04241675562383...
# 6   44.980698 -93.165090  [{'label': 'display', 'lat': 44.980698, 'lng':...
# 10  44.979020 -93.261520  [{'label': 'display', 'lat': 44.97901980661695...
# 11  44.949676 -93.262592  [{'label': 'display', 'lat': 44.94967599765591...
# 13  44.950196 -93.298415  [{'label': 'display', 'lat': 44.95019627835658...
# 28  44.978163 -93.229896  [{'label': 'display', 'lat': 44.97816284161655...
# 29  44.968395 -93.208237  [{'label': 'display', 'lat': 44.96839487552816...
# 33  44.964715 -93.236017  [{'label': 'display', 'lat': 44.96471469898935...
#
#     distance postalCode  cc              city state        country  \
# 0       7430      55113  US         Roseville    MN  United States
# 2       3232      55403  US       Minneapolis    MN  United States
# 3       3320      55403  US       Minneapolis    MN  United States
# 4       8344      55421  US  Columbia Heights    MN  United States
# 6       5962      55108  US        Saint Paul    MN  United States
# 10      2206      55415  US       Minneapolis    MN  United States
# 11      2759      55407  US       Minneapolis    MN  United States
# 13      5103      55408  US       Minneapolis    MN  United States
# 28      1349      55414  US       Minneapolis    MN  United States
# 29      2387        NaN  US        Saint Paul    MN  United States
# 33       386        NaN  US       Minneapolis    MN  United States
#
#                                      formattedAddress         crossStreet  \
# 0   [10 Rosedale Ctr, Roseville, MN 55113, United ...                 NaN
# 2              [Minneapolis, MN 55403, United States]                 NaN
# 3   [516 2nd Ave N (I-394), Minneapolis, MN 55403,...               I-394
# 4   [4079 Central Ave NE, Columbia Heights, MN 554...                 NaN
# 6               [Saint Paul, MN 55108, United States]                 NaN
# 10  [3rd St (5th Ave), Minneapolis, MN 55415, Unit...             5th Ave
# 11  [2950 Chicago Ave S (btw Lake & 29th St), Minn...  btw Lake & 29th St
# 13  [2860 Hennepin Ave S (at W 29th St), Minneapol...        at W 29th St
# 28             [Minneapolis, MN 55414, United States]                 NaN
# 29  [University (Emerald), Saint Paul, MN, United ...             Emerald
# 33  [4th St SE (19th Ave), Minneapolis, MN, United...            19th Ave
#
#    neighborhood                        id
# 0           NaN  4bf29a70a32e20a1f261d557
# 2           NaN  50170b1fe4b0c3d592d66512
# 3           NaN  4d9ce4957865a0934ea3db7a
# 4           NaN  4dfa968b149557de37aaa336
# 6           NaN  57ce4e3e498e532c6b0e8a7a
# 10          NaN  4c3e26da80bc20a1c99caa58
# 11          NaN  4b10955ff964a520457323e3
# 13          NaN  4acd318af964a52055cb20e3
# 28          NaN  500f2242e4b00fee85cf27c5
# 29          NaN  4cf3d07588de3704ea37812b
# 33          NaN  4d5069d7d7eaa1432b96670f

# %%
df2['postalCode'].value_counts()
# Out:
# 55403    2
# 55408    1
# 55407    1
# 55108    1
# 55421    1
# 55414    1
# 55113    1
# 55415    1
# Name: postalCode, dtype: int64

# %% [markdown]
# Based on the counts above the only applicable postal codes shown are 55403 (Downtwon West, North Loop), and 55414 (University). If we are to rank which neighborhoods have the most "transit stations" it would look like this:
# - Downtown West (2)
# - North Loop (2)
# - University (1)
#
# We see Downton West and North Loop are tied for the top rank with two counts, and Univeristy is ranked last with only one count.

# %% [markdown]
# # Neighborhood Ranking

# %%
data = {
        'availability_rank': [6.0,5.0,4.0,3.0,2.0,1.0],
        'SCR_rank': [6.0,3.0,4.0,1.0,5.0,2.0],
        'nearest_distance_rank': [5.0,3.0,4.0,6.0,1.0,2.0],
        'transit_center_rank': [6.0,'NaN',5.0,'NaN',6.0,'NaN']
       }

rank_table = pd.DataFrame (data, 
        columns = ['availability_rank','SCR_rank','nearest_distance_rank','transit_center_rank'],
        index = ['Downtown West','Marcy Holmes','University','Cedar Riverside','North Loop','Prospect Park']
        )
rank_table
# Out:
#                  availability_rank  SCR_rank  nearest_distance_rank  \
# Downtown West                  6.0       6.0                    5.0
# Marcy Holmes                   5.0       3.0                    3.0
# University                     4.0       4.0                    4.0
# Cedar Riverside                3.0       1.0                    6.0
# North Loop                     2.0       5.0                    1.0
# Prospect Park                  1.0       2.0                    2.0
#
#                 transit_center_rank
# Downtown West                     6
# Marcy Holmes                    NaN
# University                        5
# Cedar Riverside                 NaN
# North Loop                        6
# Prospect Park                   NaN

# %%
rank_table['average'] = rank_table.mean(numeric_only=True, axis=1)
rank_table
# Out:
#                  availability_rank  SCR_rank  nearest_distance_rank  \
# Downtown West                  6.0       6.0                    5.0
# Marcy Holmes                   5.0       3.0                    3.0
# University                     4.0       4.0                    4.0
# Cedar Riverside                3.0       1.0                    6.0
# North Loop                     2.0       5.0                    1.0
# Prospect Park                  1.0       2.0                    2.0
#
#                 transit_center_rank   average
# Downtown West                     6  5.666667
# Marcy Holmes                    NaN  3.666667
# University                        5  4.000000
# Cedar Riverside                 NaN  3.333333
# North Loop                        6  2.666667
# Prospect Park                   NaN  1.666667

# %%
rank_table2 = rank_table.sort_values(by=['average'], ascending=False)
rank_table2
# Out:
#                  availability_rank  SCR_rank  nearest_distance_rank  \
# Downtown West                  6.0       6.0                    5.0
# University                     4.0       4.0                    4.0
# Marcy Holmes                   5.0       3.0                    3.0
# Cedar Riverside                3.0       1.0                    6.0
# North Loop                     2.0       5.0                    1.0
# Prospect Park                  1.0       2.0                    2.0
#
#                 transit_center_rank   average
# Downtown West                     6  5.666667
# University                        5  4.000000
# Marcy Holmes                    NaN  3.666667
# Cedar Riverside                 NaN  3.333333
# North Loop                        6  2.666667
# Prospect Park                   NaN  1.666667

# %% [markdown]
# Based on the ranking table above the best neighborhood to place a scooter maintenance facility based upon our criteria is Downtown West. The next best neighborhood would be Univeristy, etc...
